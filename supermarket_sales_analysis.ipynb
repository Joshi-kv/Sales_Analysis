# %%
import pandas as pd

# %%
#reading data file
data=pd.read_csv('sales.csv')

# %%
data
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
#to print first 10 data
data.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
#to print last 10 data
data.tail(10)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 990   Clothing     25         4    100    Cash       5
# 991  Furniture     96         7    672    Card       3
# ...

# %%
#printing unique values of a column
data['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
#fetching data of a particular index
data.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
#fetching values using conditions.
data[data['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data[data['Payment']=='Gpay']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13    942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14    547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 982   741817151  2/10/2018  14:43  Female   Brookfield  NewYork     No
# 983   169440268  2/17/2018  14:42  Female   Brookfield  NewYork     No
# 984   979059991  3/26/2018  13:48  Female   Brookfield  NewYork    Yes
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 3     Sporting     89         4    356    Gpay       1
# ...

# %%
data[data['Quantity']>5]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 13    942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14    547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 16    397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 20    619639105  3/26/2018  19:48  Female   Brookfield  NewYork     No
# 27    103072863  3/12/2018  11:57    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 985   266635768  1/29/2018  14:30    Male  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 13    Clothing      9         6     54    Gpay       5
# ...

# %%
#arithmetic operations 
data.sum()['Total']
# Out:
# 207788

# %%
data.mean()['Total']
# Out:
# C:\Users\JOSHI\AppData\Local\Temp\ipykernel_5184\2945631426.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()['Total']
# 207.788

# %%
data.median()['Quantity']
# Out:
# C:\Users\JOSHI\AppData\Local\Temp\ipykernel_5184\3898390501.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()['Quantity']
# 4.0

# %%
#groupby function
data.groupby('Payment').sum()['Total']
# Out:
# Payment
# Card    64264
# Cash    72643
# Gpay    70881
# Name: Total, dtype: int64

# %%
data.groupby('Category').sum()['Price']
# Out:
# Category
# Books        8599
# Clothing     8683
# Fashion      8055
# Furniture    8188
# Groceries    8372
# Sporting     9215
# Name: Price, dtype: int64

# %%
#finding which location has highest and lowest sales.
location_list=data.groupby('Location')
location=[x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
import matplotlib.pyplot as plt
data.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
plt.bar(location,data.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(data.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1ad8bd143a0>,
# ...
#  [Text(0.5080357843151302, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.2771104278082528, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
#which location has more male and female customer
gender_sales=data.groupby(['Gender','Location']).count()['Invoice ID']
gender_sales.unstack(level=0)
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
gender_sales.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#which day of month has more sales
#adding a new column day by extracting day from date column
data['Day']=pd.to_datetime(data['Date']).dt.day

# %%
data.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
day_sales=data.groupby('Day').sum()['Total']

# %%
day_sales.plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
#which branch has more and less members
members=data.groupby(['Member','Location']).count()['Invoice ID']
members.unstack(level=0)
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
members.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#which branch has more rating
rating=data.groupby('Location').mean()['Rating']
rating.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#which city has more female and male customers
city=data.groupby(['Gender','City']).count()['Invoice ID']
city.unstack(level=0)
# Out:
# Gender   Female  Male
# City
# Chicago     143   185
# Dallas      179   153
# NewYork     179   161

# %%
city.unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
#Which product category has more sales
category=data.groupby('Category').sum()['Total']
category.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>
